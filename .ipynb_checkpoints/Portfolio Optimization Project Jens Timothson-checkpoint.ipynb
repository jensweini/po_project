# %% [markdown]
# # Semester Project Portfolio Optimization Spring 2019
# Jens Weinekötter, Timothson Peterson

# %%
# Import packages
import pandas as pd
import numpy as np
import gurobipy as gb
import matplotlib.pyplot as plt
# %config IPCompleter.greedy=True

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### a)

# %%
#provide data 
df_main = pd.read_csv('prices1617.csv',index_col = 'date')
df_main.head()
# Out:
#              SGS  SWISSCOM  GIVAUDAN  ZURICH INSURANCE  NOVARTIS  ROCHE  \
# date
# 2016-01-01  1911     503.0      1823             258.4     86.80  276.4
# 2016-01-08  1757     488.3      1714             241.4     82.10  263.0
# 2016-01-15  1770     478.2      1772             242.8     80.35  256.5
# 2016-01-22  1932     489.0      1812             224.4     82.90  265.3
# 2016-01-29  1983     507.5      1907             225.8     78.50  263.9
#
#             CREDIT SUISSE  ADECCO  LAFARGEHOLCIM    ABB   ...       LONZA  \
# date                                                      ...
# 2016-01-01         20.929  68.047          50.30  17.96   ...     151.078
# 2016-01-08         19.028  62.368          46.00  16.43   ...     143.668
# 2016-01-15         18.054  59.356          42.26  16.18   ...     138.017
# 2016-01-22         17.359  60.837          44.12  16.77   ...     143.575
# 2016-01-29         17.369  61.726          42.92  17.57   ...     144.779
#
# ...

# %%
#index change
df_main.index = pd.to_datetime(df_main.index)
df_main.head()
# Out:
#              SGS  SWISSCOM  GIVAUDAN  ZURICH INSURANCE  NOVARTIS  ROCHE  \
# date
# 2016-01-01  1911     503.0      1823             258.4     86.80  276.4
# 2016-01-08  1757     488.3      1714             241.4     82.10  263.0
# 2016-01-15  1770     478.2      1772             242.8     80.35  256.5
# 2016-01-22  1932     489.0      1812             224.4     82.90  265.3
# 2016-01-29  1983     507.5      1907             225.8     78.50  263.9
#
#             CREDIT SUISSE  ADECCO  LAFARGEHOLCIM    ABB   ...       LONZA  \
# date                                                      ...
# 2016-01-01         20.929  68.047          50.30  17.96   ...     151.078
# 2016-01-08         19.028  62.368          46.00  16.43   ...     143.668
# 2016-01-15         18.054  59.356          42.26  16.18   ...     138.017
# 2016-01-22         17.359  60.837          44.12  16.77   ...     143.575
# 2016-01-29         17.369  61.726          42.92  17.57   ...     144.779
#
# ...

# %%
 df_p1 = df_main.drop('SMI', axis=1)

# %%
#compute wwekly returns on each stock
df_main_return = (df_main / df_main.shift(1) - 1).dropna()

df_p1_return = (df_p1 / df_p1.shift(1) - 1).dropna()
df_p1_return.head()
# Out:
#                  SGS  SWISSCOM  GIVAUDAN  ZURICH INSURANCE  NOVARTIS  \
# date
# 2016-01-08 -0.080586 -0.029225 -0.059792         -0.065789 -0.054147
# 2016-01-15  0.007399 -0.020684  0.033839          0.005800 -0.021315
# 2016-01-22  0.091525  0.022585  0.022573         -0.075783  0.031736
# 2016-01-29  0.026398  0.037832  0.052428          0.006239 -0.053076
# 2016-02-05 -0.000504 -0.049261 -0.027268         -0.054916 -0.058599
#
#                ROCHE  CREDIT SUISSE    ADECCO  LAFARGEHOLCIM       ABB  \
# date
# 2016-01-08 -0.048480      -0.090831 -0.083457      -0.085487 -0.085189
# 2016-01-15 -0.024715      -0.051188 -0.048294      -0.081304 -0.015216
# 2016-01-22  0.034308      -0.038496  0.024951       0.044013  0.036465
# 2016-01-29 -0.005277       0.000576  0.014613      -0.027199  0.047704
# 2016-02-05 -0.044335      -0.169440 -0.042397      -0.091100  0.001707
#
#               SWATCH     LONZA  SWISS LIFE   GEBERIT    NESTLE  JULIUS BAER  \
# date
# ...

# %% [markdown]
# ### b)
# risk measures 05_risk measures and 06_mean variance portfolio

# %%
# Get array of stocks (without index SMI)
stocks = df_main_return.columns.drop('SMI')
stocks
# Out:
# Index(['SGS', 'SWISSCOM', 'GIVAUDAN', 'ZURICH INSURANCE', 'NOVARTIS', 'ROCHE',
#        'CREDIT SUISSE', 'ADECCO', 'LAFARGEHOLCIM', 'ABB', 'SWATCH', 'LONZA',
#        'SWISS LIFE', 'GEBERIT', 'NESTLE', 'JULIUS BAER', 'SWISS RE',
#        'RICHEMONT', 'UBS', 'SIKA'],
#       dtype='object')

# %%
# Compute expected returns 
expected_returns = df_main_return[stocks].mean()
expected_returns
# Out:
# SGS                 0.003030
# SWISSCOM            0.000484
# GIVAUDAN            0.002294
# ZURICH INSURANCE    0.001777
# NOVARTIS           -0.000143
# ROCHE              -0.000754
# CREDIT SUISSE      -0.000436
# ADECCO              0.001316
# LAFARGEHOLCIM       0.001546
# ABB                 0.003941
# SWATCH              0.001901
# LONZA               0.005751
# SWISS LIFE          0.002690
# GEBERIT             0.002500
# NESTLE              0.001295
# JULIUS BAER         0.002501
# SWISS RE           -0.000377
# RICHEMONT           0.002426
# UBS                 0.000021
# SIKA                0.007679
# dtype: float64

# %% [markdown]
# ### c)

# %%
sdfasdfsdf

# %% [markdown]
# ### d)

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### a)

# %% [markdown]
# ### b)

# %% [markdown]
# ### c)

# %% [markdown]
# ## Task 4

# %% [markdown]
# ### a)

# %% [markdown]
# ### b)

# %% [markdown]
# ### c)

# %% [markdown]
# ### d)

# %% [markdown]
# ## Task 5

# %% [markdown]
# ### a)

# %% [markdown]
# ### b)

# %% [markdown]
# ### c)

# %% [markdown]
# ### d)
